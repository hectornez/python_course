# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import cufflinks as cf
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = pd.read_excel('frq_incendios2006_2015_dd-web_tcm30-525841.xlsx', sheet_name='Datos2006_2015')

# %%
data.head()
# Out:
#      NOMBRE  CODIGOINE  NUT2  PRO_INE   PRO_N_INE  conatos  incendios  \
# 0  A Arnoia      32003    11       32     Ourense       27          3
# 1    A Baña      15007    11       15    A Coruña       66         37
# 2    A Bola      32014    11       32     Ourense       74         12
# 3  A Cañiza      36009    11       36  Pontevedra      330         81
# 4  A Capela      15018    11       15    A Coruña       12          6
#
#    ARBOLADO  NOARBOLADO  TOTAL  TOTAL_INCENDIOS COM_N_INE
# 0        30           8     38               30   Galicia
# 1       615          82    697              103   Galicia
# 2        16          61     77               86   Galicia
# 3       978        1260   2238              411   Galicia
# 4       394         165    559               18   Galicia

# %%
df = pd.DataFrame(data)

# %%
df.groupby(['PRO_N_INE'], sort=True,axis=1)

# %%
df.head(20)
# Out:
#                   NOMBRE  CODIGOINE  NUT2  PRO_INE   PRO_N_INE  conatos  \
# 0               A Arnoia      32003    11       32     Ourense       27
# 1                 A Baña      15007    11       15    A Coruña       66
# 2                 A Bola      32014    11       32     Ourense       74
# 3               A Cañiza      36009    11       36  Pontevedra      330
# 4               A Capela      15018    11       15    A Coruña       12
# 5               A Coruña      15030    11       15    A Coruña      149
# 6              A Estrada      36017    11       36  Pontevedra      156
# 7           A Fonsagrada      27018    11       27        Lugo       75
# 8               A Guarda      36023    11       36  Pontevedra       33
# 9               A Gudiña      32034    11       32     Ourense      426
# 10      A Illa de Arousa      36901    11       36  Pontevedra       30
# 11                A Lama      36025    11       36  Pontevedra       58
# 12             A Laracha      15041    11       15    A Coruña       86
# 13               A Merca      32047    11       32     Ourense       80
# 14            A Mezquita      32048    11       32     Ourense      326
# 15           A Pastoriza      27044    11       27        Lugo       35
# 16              A Peroxa      32059    11       32     Ourense       62
# 17     A Pobra de Trives      32063    11       32     Ourense      339
# 18    A Pobra do Brollón      27047    11       27        Lugo       56
# 19  A Pobra do Caramiñal      15067    11       15    A Coruña       94
#
#     incendios  ARBOLADO  NOARBOLADO  TOTAL  TOTAL_INCENDIOS COM_N_INE
# 0           3        30           8     38               30   Galicia
# 1          37       615          82    697              103   Galicia
# 2          12        16          61     77               86   Galicia
# 3          81       978        1260   2238              411   Galicia
# 4           6       394         165    559               18   Galicia
# 5          24        18         104    122              173   Galicia
# 6          54       262         791   1053              210   Galicia
# 7          47       600         641   1241              122   Galicia
# 8           4         8          17     25               37   Galicia
# 9         273       803        3395   4198              699   Galicia
# 10          3        30           6     36               33   Galicia
# 11         62       364        1558   1922              120   Galicia
# 12         28       608         806   1414              114   Galicia
# 13         16       189         317    506               96   Galicia
# 14        283       294        3125   3419              609   Galicia
# 15         11         7          25     32               46   Galicia
# 16         27       249         114    363               89   Galicia
# 17        113        66         535    601              452   Galicia
# 18         12        36          33     69               68   Galicia
# 19         22       141         120    261              116   Galicia

# %%
plt.figure(figsize=[16,16])
sns.barplot(x='TOTAL_INCENDIOS', y='PRO_N_INE', data = df, orient='h')
